# %%
from google.colab import drive
import numpy as np
import pandas as pd
import pickle

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/CS 547/DeepDiveProject"
# Out:
# 'Column descriptions.xlsx'   Crimes_-_2001_to_Present.csv   data_extraction.ipynb   README.gdoc

# %%
df = pd.read_csv("/content/drive/My Drive/CS 547/DeepDiveProject/Crimes_-_2001_to_Present.csv")

# %%
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11037294    JA371270  03/18/2015 12:00:00 PM     0000X W WACKER DR  1153
# 1  11646293    JC213749  12/20/2018 03:00:00 PM  023XX N LOCKWOOD AVE  1154
# 2  11645836    JC212333  05/01/2016 12:25:00 AM   055XX S ROCKWELL ST  1153
# 3  11645959    JC211511  12/20/2018 04:00:00 PM    045XX N ALBANY AVE  2820
# 4  11645601    JC212935  06/01/2014 12:01:00 AM   087XX S SANGAMON ST  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       OTHER OFFENSE                         TELEPHONE THREAT
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
df["Updated On"] = pd.to_datetime(df["Updated On"])
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# <ipython-input-7-06cc8108275c>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Updated On"] = pd.to_datetime(df["Updated On"])

# %%
debugging_dataset = df.sample(frac=0.01, random_state=42)
working_dataset = df.drop(debugging_dataset.index)

# %%
debugging_dataset_path = "/content/drive/My Drive/CS 547/DeepDiveProject/debugging_dataset.pickle"
debugging_dataset.to_pickle(debugging_dataset_path)

working_dataset_path = "/content/drive/My Drive/CS 547/DeepDiveProject/working_dataset.pickle"
working_dataset.to_pickle(working_dataset_path)

# %%
# test extraction
with open(debugging_dataset_path, 'rb') as file:
    debugging_data = pickle.load(file)

# %%
debugging_data.head()
# Out:
#                ID Case Number                Date               Block  IUCR  \
# 7247585  10731773    HZ491119 2016-10-26 14:40:00   015XX W CERMAK RD  0560
# 4582505   4122804    HL459012 2005-07-02 21:15:00     009XX E 52ND ST  1310
# 314531   13503572    JH315821 2024-06-21 17:30:00  005XX S PULASKI RD  0440
# 7168398  10804888    JA103910 2017-01-03 23:30:00     007XX E 51ST ST  031A
# 2862173   2001495    HH203428 2002-02-22 23:26:54     064XX S KING DR  0460
#
#             Primary Type                                        Description  \
# 7247585          ASSAULT                                             SIMPLE
# 4582505  CRIMINAL DAMAGE                                        TO PROPERTY
# 314531           BATTERY  AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR IN...
# 7168398          ROBBERY                                     ARMED: HANDGUN
# 2862173          BATTERY                                             SIMPLE
#
# ...
